# %%
# %load_ext autoreload
# %autoreload 2

import importlib
import Data.cargar_datos as data
import fases.fase_1_depuración_inicial.depuracion_columnas as dc
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
importlib.reload(data)
# Out:
# <module 'Data.cargar_datos' from 'c:\\ARCHIVOS PC\\ARCHIVOS PC\\TRABAJOS UNIVERSIDAD\\PRACTICAS\\EPIDEMIOLOGIA\\Pipeline_Susana_Lopez\\Data\\cargar_datos.py'>

# %%
df = data.cargar_database()
# Out:
# Leyendo cache...

# %%
for i, col in enumerate(df.columns):
    print(f'  [{i + 1:02d}] {col:<40}')
# Out:
#   [01] OID
#   [02] HCNTIPHIS
#   [03] HCCODIGO
#   [04] HCNOMBRE
#   [05] NUM_FOLIO
#   [06] FECHA_FOLIO
#   [07] MES_VERIFICADO_X_FECHA_FOLIO
#   [08] AÑO_VERIFICADO_X_FECHA_FOLIO
#   [09] GENPACIEN
#   [10] TIPO_IDENTIFICACION
#   [11] HC_IDENTIFICACION
#   [12] NOMBRE_PACIENTE
#   [13] GENERO
#   [14] GRADO_ESTUDIO
#   [15] GDECODIGO
#   [16] EAPB
#   [17] REGIMEN
#   [18] TIPO_PACIENTE
#   [19] MUNICIPIO
#   [20] BARRIO_O_VEREDA
#   [21] DIRECCION
#   [22] ZONA
#   [23] COD_PAIS
#   [24] PAIS
#   [25] FECHA_INGRESO_AL_HSLV
#   [26] MES_VERIFICADO_X_FECHA_INGRESO_AL_HSLV
#   [27] AÑO_VERIFICADO_X_FECHA_INGRESO_AL_HSLV
#   [28] EDAD_PACIENTE
#   [29] FECHA_NACIMIENTO
#   [30] NIVEL_SOCIOECONOMICO
#   [31] ETNÍA
#   [32] ADNINGRESO
#   [33] INGRESO_PAC
#   [34] GENARESER
#   [35] GASCODIGO
#   [36] GASNOMBRE
#   [37] ADNCENATE1
#   [38] CENTRO_ATENCION
#   [39] HCCAUEXT
#   [40] HCFINCON
#   [41] HCFOLABR
#   [42] GENMEDICO
#   [43] GMECODIGO
#   [44] NOMBRE_MEDICO
#   [45] GENESPECI
#   [46] ESPECIALIDAD
#   [47] GENMEDICOA
#   [48] HCNINDMED
#   [49] HCNINDSAL
#   [50] HCNORDHOSP
#   [51] HCNAUTINTV
#   [52] HCNINCAPA
#   [53] CMNCITMED
#   [54] GENDETCON
#   [55] OPTIMISTICLOCKFIELD
#   [56] HCNOBSGRAL
#   [57] HCNREGANST
#   [58] HCNFOLDATAD
#   [59] HCFOLUNIF
#   [60] HCVALHLLDGT
#   [61] HPNDEFCAM
#   [62] HCFECFOLI
#   [63] HCNFECCONF
#   [64] HCFOLWEB
#   [65] HCNLISTANTE
#   [66] OID_DIAPAC
#   [67] HCNFOLIO
#   [68] GENDIAGNO
#   [69] TIP_DX
#   [70] OID_GENDIAGNO
#   [71] DIAGNOSTICO
#   [72] DIAG_NOMBRE
#   [73] DIAGNO_COMPLETO
#   [74] GENOCUPACION
#   [75] OCUPACION_PACIENTE

# %%
df_limpio = dc.depurar_columnas(df)
print(df_limpio)

# %%
filas, columnas = df_limpio.shape
print(f"\nEl DataFrame depurado tiene {filas} filas y {columnas} columnas.")
# Out:
# El DataFrame depurado tiene 198132 filas y 17 columnas.
